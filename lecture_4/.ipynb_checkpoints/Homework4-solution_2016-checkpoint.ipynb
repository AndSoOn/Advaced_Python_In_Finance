# %% [markdown]
# # Homework Set 4

# %% [markdown]
# The problem 1 can be challenging in programming, so we suggest you to work on Problem 2 first, using the tension spline interpolation as part of the lin package in the class library.
#
# ## Problem 1:
#
# use the following data set:

# %%
# %pylab inline 
import pandas as pd
import sys
print sys.path
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ['', '//anaconda/lib/python2.7/site-packages/tweepy-3.3.0-py2.7.egg', '//anaconda/lib/python2.7/site-packages/requests_oauthlib-0.5.0-py2.7.egg', '//anaconda/lib/python2.7/site-packages/oauthlib-0.7.2-py2.7.egg', '//anaconda/lib/python2.7/site-packages/pydelicious-0.6-py2.7.egg', '//anaconda/lib/python2.7/site-packages/feedparser-5.2.1-py2.7.egg', '//anaconda/lib/python27.zip', '//anaconda/lib/python2.7', '//anaconda/lib/python2.7/plat-darwin', '//anaconda/lib/python2.7/plat-mac', '//anaconda/lib/python2.7/plat-mac/lib-scriptpackages', '//anaconda/lib/python2.7/lib-tk', '//anaconda/lib/python2.7/lib-old', '//anaconda/lib/python2.7/lib-dynload', '/anaconda/lib/python2.7/site-packages/Sphinx-1.3.1-py2.7.egg', '/anaconda/lib/python2.7/site-packages/setuptools-19.6.2-py2.7.egg', '//anaconda/lib/python2.7/site-packages', '//anaconda/lib/python2.7/site-packages/PIL', '//anaconda/lib/python2.7/site-packages/IPython/extensions', '/Users/ZHHR/.ipython']
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 29 days

# %%
import fmt

x = np.array([.01, .03, .07, .1, .6])
y = np.array([.0095, .023, .035, .040, .042])
dx = .01
xd = arange(.01, .65, dx) # dense grid to be valued

df = pd.DataFrame(np.array([x, y]), index=['x', 'y'])
fmt.displayDF(df)
# Out:
# <center><font size=2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>x</th>
#       <td>0.0100</td>
#       <td>0.0300</td>
#       <td>0.0700</td>
#       <td>0.1000</td>
#       <td>0.6000</td>
#     </tr>
#     <tr>
#       <th>y</th>
#       <td>0.0095</td>
#       <td>0.0230</td>
#       <td>0.0350</td>
#       <td>0.0400</td>
#       <td>0.0420</td>
#     </tr>
#   </tbody>
# </table></font></center>

# %% [markdown]
# Implement the rational tension spline using the fast triagular thomas algorithm:
#
# 1. do your own reading and research on <a href=http://en.wikipedia.org/wiki/Tridiagonal_matrix_algorithm>Thomas algorithm</a> for solving the tri-diagonal matrix, and implement and test it in python.
# 2. implement the tension spline interpolation method using your own tridiagonal solver, test your tension spline interpolation by reproducing the figures in the lecture slides 2-14, titled "Tension spline examples", using the data given above.
# 3. (Optional) write a python function to compute the length of curve $y=y(x)$ from $x=a$ to $x=b$ for the tension spline. Intuitively, the stronger the tension, the shorter the curve length. Use your function to verify if your intuition is correct. You can use the simple rectangular rule to compute the numerical integral, or use existing python functions like ```scipy.integrate.simps```

# %% [markdown]
# ### Solution
#
# 1: the thomas algorithm:

# %%
def tridiagSolver(a, b, c, d) :
    nf = len(a)     # number of equations
    ac, bc, cc, dc = map(np.array, (a, b, c, d))     # copy the array
    for it in xrange(1, nf):
        mc = ac[it]/bc[it-1]
        bc[it] = bc[it] - mc*cc[it-1] 
        dc[it] = dc[it] - mc*dc[it-1]
 
    xc = ac
    xc[-1] = dc[-1]/bc[-1]
 
    for il in xrange(nf-2, -1, -1):
        xc[il] = (dc[il]-cc[il]*xc[il+1])/bc[il]
 
    return xc

n = 100
m = np.eye(n)*2
np.fill_diagonal(m, 1. + np.random.normal(size=[n]))
np.fill_diagonal(m[:,1:], np.random.normal(size=[n-1]))
np.fill_diagonal(m[1:,:], np.random.normal(size=[n-1]))

a = np.append([0], m[1:,:].diagonal())
b = m.diagonal()
c= np.append(m[:,1:].diagonal(), [0])
d = np.random.normal(size=[n])

x1 = tridiagSolver(a, b, c, d)
x2 = np.linalg.solve(m, d)

print "Thomas algo matches direct matrix solver:", np.allclose(x1, x2)
# Out:
# Thomas algo matches direct matrix solver: True

# %% [markdown]
# 2: tension spline using Tridiagonal inversion

# %%
from scipy.integrate import simps
import trid

def line_length(ts, xd) :
    dx = np.diff(xd)
    c = np.sqrt(1. + ts.deriv(xd)**2)
    return simps(c, xd)

lbds = [0, 2, 20, 100]
ll = []

plot(x, y, 'o');
title('Tension Spline');

for lbd in lbds:
    ts = trid.TridiagTension(lbd)
    ts.build(x, y)
    plot(xd, ts.value(xd))
    ll.append(line_length(ts, xd))
    
legend(['data'] + ['$\lambda = %.f$' % l for l in lbds], loc='best');

# %% [markdown]
# 3: The curve length as a function of the tension parameter

# %%
fmt.displayDF(pd.DataFrame(np.array([lbds, ll]), index=['Tension', 'Curve Length']))
# Out:
# <center><font size=2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Tension</th>
#       <td>0.0000</td>
#       <td>2.0000</td>
#       <td>20.0000</td>
#       <td>100.0000</td>
#     </tr>
#     <tr>
#       <th>Curve Length</th>
#       <td>0.6378</td>
#       <td>0.6369</td>
#       <td> 0.6365</td>
#       <td>  0.6365</td>
#     </tr>
#   </tbody>
# </table></font></center>

# %% [markdown]
# ## Problem 2
#
# Given the following benchmark swap quotes for USD, suppose all swap coupons are paid semi-annually:

# %%
mats = np.array([1, 2, 3, 5, 7, 10, 12, 15, 20, 25])*1.
par = np.array([.042, .043, .047, .054, .057, .06, .061, .059, .056, .0555])

df_swap = pd.DataFrame(np.array([par]).T*100, columns=["Par Spread (%)"], 
                       index=map(lambda m: '%dY' % m, mats))
fmt.displayDF(df_swap.T, 2, 2)
# Out:
# <center><font size=2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1Y</th>
#       <th>2Y</th>
#       <th>3Y</th>
#       <th>5Y</th>
#       <th>7Y</th>
#       <th>10Y</th>
#       <th>12Y</th>
#       <th>15Y</th>
#       <th>20Y</th>
#       <th>25Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Par Spread (%)</th>
#       <td>4.2</td>
#       <td>4.3</td>
#       <td>4.7</td>
#       <td>5.4</td>
#       <td>5.7</td>
#       <td>6.0</td>
#       <td>6.1</td>
#       <td>5.9</td>
#       <td>5.6</td>
#       <td>5.5</td>
#     </tr>
#   </tbody>
# </table></font></center>

# %% [markdown]
# you can use the class ```Swap``` and the pricing function ```priceSwap``` defined in <a href=https://raw.githubusercontent.com/yadongli/nyumath2048/master/lib/swap.py>swap.py</a>, which prices a receiver swap. Note this is a simplified pricing function that ignores all the details like day count conventions.
#
# The following are some sample codes of how to use the swap pricers:

# %%
from swap import Swap, priceSwap
import lin

# the pricing function if curve(t) is the cumulative yield, ie, -log(b(t))
def y2pv(swap, curve) :
    discf = lambda ts: np.exp(-curve(ts))
    return priceSwap(swap, discf)

# create the benchmark instruments
bm_swaps = {Swap(m, c, 2) : 0 for m, c in zip (mats, par)}

# price a single swap with a straight curve in y(t)
flat = lin.RationalTension(lbd = 5.)
flat.build(mats, mats*.04) # create a dummy curve

pvs = {swap.maturity : y2pv(swap, flat) for swap in bm_swaps.keys()}
print "PV by maturity"
print "\n".join(["%.2g Y : %.4g" % (m, v) for m, v in pvs.items()])
# Out:
# PV by maturity
# 1 Y : 0.00155
# 2 Y : 0.004943
# 3 Y : 0.01846
# 5 Y : 0.06101
# 7 Y : 0.1003
# 10 Y : 0.1599
# 12 Y : 0.1943
# 15 Y : 0.2077
# 20 Y : 0.2126
# 25 Y : 0.2362

# %% [markdown]
# 1. Explain what is the purpose of the +1e-6 in the first line of the priceSwap function
# 2. Write a generic function that can bootstrap the above IR swap quotes using tension spline. Design your function in a way that you can easily change the variables to be interpolated. If you have difficulties in writing your own, please feel free to reference or use the inst.bootstrap function in the class slides and library. Use the market data above to boostrap the IR curve by interpolating the cumulative yield $y(t) = -\log(b(t))$ with tension spline, where $b(t)$ is the discount factor (i.e., the price of risk free zero coupon bonds). After bootstraping the curve, re-price the benchmark instruments using the bootstrapped curve, and compute the L-2 norm of the absolute pricing errors. Show how the pricing error of the bootstraped curve depend on the tension parameter $\lambda$.
# 3. Using the iteration technique to reduce the L-2 norm of the error below 1bps, how many iteration is needed for the error to go below 1bps?
# 4. From the curve built in the previous step, compute both the $y(t)$ and the instantaneous forward rate $f(t) = -\frac{1}{b(t)}\frac{d b(t)}{d t} = \frac{d y(t)}{dt}$, and show how their shapes change with the tension parameter $\lambda$. In addition, compare the changes in the instantaneous forward rates with 1bps change in the 5Y par swap rate. You can use the deriv() method in the Tension spline class.
# 5. Build the curve by interpolating the zero rate with tension spline instead, i.e, $r(t) = \frac{y(t)}{t}$, compare how the forward rates shape and perturbations differ from those obtained in step 4, and comment on the pro and cons between interpolating $r(t)$ and $y(t)$.
# 6. Repeat the previous step, but directly interpolating the forward rates $f(t)$, and comment on whether it is suitable in practice.
#
# Hint:
# * write your code in a modular and reusable way; you can re-use the code provided as part of the class lecture, but you get extra credit if you can write your own bootstraping.
# * be careful with the choice of boundary for the root search, allow negative rates often helps stablizing the bootstraping, even though it does not make economic sense
# * in the last step, you may have to mix the old and new results to stablize the iteration, (e.g., use mixf=0.5 in the inst.iterboot function, or your own)

# %% [markdown]
# ### Solution
#
# 1: the +1e-6 is to avoid equality comparison of the floating point numbers, which can lead to errors in array size due to the imprecise nature of the floatng point numbers.
# 2: we can re-use the inst.bootstrap and inst.iterboot function, we only need to feed in different instruments and pfunc pair. The result
# shows that the bigger the tension parameter the smaller the error is.

# %%
import inst
import lin

# the pfunc if we interpolate y(t)
def y2pv(swap, curve) :
    discf = lambda ts: np.exp(-curve(ts))
    return priceSwap(swap, discf)

# build multiple curves and report error
def buildTensionCurves(bms, pfunc, lbds, x0, bds, it=2, mixf=0) :
    es = []
    cvs = []

    for lbd in lbds :
        curve, e = inst.iterboot(bms, pfunc, x0, bds=bds, lbd = lbd, its=it, make_curve=lin.RationalTension, mixf=mixf)
        es.append(e[-1])
        cvs.append(curve)
    
    return cvs, es

def plotFwd(ts, fwds, dfwds, lbdTags) :
    figure(figsize=[12, 4])
    subplot(1, 2, 1)
    
    plot(ts, fwds)

    legend(lbdTags, loc='best')
    xlabel('Time(Y)')
    title('Instantaneous forward rates');

    subplot(1, 2, 2)
    plot(ts, dfwds)

    legend(lbdTags, loc='best')
    xlabel('Time(Y)')
    title('Fwd rate changes with 1bps 5Y perturbation');

# create the benchmark instruments
bm_swaps = {Swap(m, c, 2) : 0 for m, c in zip (mats, par)}

lbds = [0, 2, 20, 500]
lbdTags = ['$\lambda$=%d' % l for l in lbds]

# %%
cvs0, es0 = buildTensionCurves(bm_swaps, y2pv, lbds, bds=[0, 2], x0=0, it=1)

xlabel('$\lambda$')
plot(lbds, es0, '.-')
xlim(0,50)
title('L-2 norm of pricing error (bps)');

# %% [markdown]
# 3: the following chart is the L-2 norm of the error after 1 additional iteration, showing all pricing error is < 1bps.

# %%
cvs, es1 = buildTensionCurves(bm_swaps, y2pv, lbds, bds=[0, 2], x0=0, it=2)

xlabel('$\lambda$')
plot(lbds, es1, '.-')
xlim(0, 50)
title('L-2 norm of pricing error (bps)');

# %% [markdown]
# 4: the following chart is the $y(t)$ and $f(t)$, and the changes in forward rate with 1bps 5Y perturbations. It shows that the perturbations with bigger tension parameters are more localized, a desirable feature.

# %%
print cvs[0].lbd
# Out:
# 0.0

# %%
ts = np.arange(.01, max(mats) + 1e-5, .01)
swap_pert = {k if k.maturity != 5 else Swap(k.maturity, k.coupon + 1e-4, k.freq):v for k, v in bm_swaps.items()}

cvsp, _ = buildTensionCurves(swap_pert, y2pv, lbds, bds=[0, 2], x0=0, it=2)

fwds = np.transpose([c.deriv(ts) for c in cvs])
dfwds = np.transpose([c1.deriv(ts) - c0.deriv(ts) for c0, c1 in zip(cvs, cvsp)])

plotFwd(ts, fwds, dfwds, lbdTags)

# %% [markdown]
# 5: we can re-use the code from earlier steps by defining new pfunc, interpolating the zero rate is also a valid choice, it has an advantage over the interpolatin of $y(t)$ as it have smaller jumps btw knot points. On the other hand, it is hard to justify the seesaw shape in the forward rates. Note that $f(t) = \frac{d y(t)}{dt} = \frac{d (t \cdot r(t))}{dt} = r(t) + \frac{d r(t)}{dt}$

# %%
# the pfunc if we interpolate zero rate r(t)
def r2pv(swap, curve) :
    discf = lambda ts: np.exp(-curve(ts)*ts)
    return priceSwap(swap, discf)

cvs_r, _ = buildTensionCurves(bm_swaps, r2pv, lbds, x0=.04, it=2, bds=[-.1, .1])
cvsp_r, _ = buildTensionCurves(swap_pert, r2pv, lbds, x0=.04, it=2, bds=[-.1, .1])

fwds = np.transpose([c.deriv(ts) + c(ts) for c in cvs_r])
dfwds = np.transpose([c1.deriv(ts) + c1(ts) - c0.deriv(ts) - c0(ts)  for c0, c1 in zip(cvs_r, cvsp_r)])

plotFwd(ts, fwds, dfwds, lbdTags)

# %% [markdown]
# 6: similar to what's discussed in class, applying the tension spline to forward rates are disastrous

# %%
# the pfunc if we interpolate zero rate r(t)
def f2pv(swap, curve) :
    discf = lambda ts: np.exp(-curve.integral(ts))
    return priceSwap(swap, discf)

cvs_f, _ = buildTensionCurves(bm_swaps, f2pv, lbds, x0=.04, it=5, bds=[-1, 1], mixf=0.5)
cvsp_f, _ = buildTensionCurves(swap_pert, f2pv, lbds, x0=.04, it=5, bds=[-1, 1], mixf=0.5)

fwds = np.transpose([c(ts) for c in cvs_f])
dfwds = np.transpose([c1(ts) - c0(ts)  for c0, c1 in zip(cvs_f, cvsp_f)])

plotFwd(ts, fwds, dfwds, lbdTags)

# %%
cvs, e1 = bootstrap(bm_swaps, y2pv, 0, lbds, [-2, 2], 2)
cvs_pert, e2 = bootstrap(bm_ps, y2pv, 0, lbds, [-2, 2], 2)

r1 = np.array([i.deriv(t) for i in cvs])
r1_term = np.array([i.deriv(mats) for i in cvs])
r2 = np.array([p.deriv(t) - q.deriv(t) for p, q in zip(cvs, cvs_pert)])
r2_term = np.array([p.deriv(mats) - q.deriv(mats) for p, q in zip(cvs, cvs_pert)])
